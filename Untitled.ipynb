# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('../DATA/stock_market_data.csv')

# %%
df.head()
# Out:
#         Price               Close            Close.1             Close.2  \
# 0      Ticker                AAPL               MSFT                TSLA
# 1        Date                 NaN                NaN                 NaN
# 2  2018-01-02   40.34188461303711  79.05035400390625  21.368667602539062
# 3  2018-01-03   40.33486557006836  79.41828155517578  21.149999618530273
# 4  2018-01-04  40.522220611572266  80.11727142333984  20.974666595458984
#
#                 High             High.1              High.2  \
# 0               AAPL               MSFT                TSLA
# 1                NaN                NaN                 NaN
# 2   40.3512542876815   79.3814555361966  21.474000930786133
# 3  40.87819243452449  79.56544097743182  21.683332443237305
# 4  40.62526561027816  80.62312314498602   21.23666763305664
#
#                   Low              Low.1               Low.2  \
# 0                AAPL               MSFT                TSLA
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2038 entries, 0 to 2037
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Price     2038 non-null   object
#  1   Close     2037 non-null   object
#  2   Close.1   2037 non-null   object
#  3   Close.2   2037 non-null   object
#  4   High      2037 non-null   object
#  5   High.1    2037 non-null   object
#  6   High.2    2037 non-null   object
#  7   Low       2037 non-null   object
#  8   Low.1     2037 non-null   object
#  9   Low.2     2037 non-null   object
#  10  Open      2037 non-null   object
#  11  Open.1    2037 non-null   object
#  12  Open.2    2037 non-null   object
#  13  Volume    2037 non-null   object
#  14  Volume.1  2037 non-null   object
#  15  Volume.2  2037 non-null   object
# dtypes: object(16)
# memory usage: 254.9+ KB

# %%
df.describe()
# Out:
#          Price               Close             Close.1            Close.2  \
# count     2038                2037                2037               2037
# unique    2038                2014                2014               2005
# top     Ticker  237.64962768554688  131.62493896484375  207.8300018310547
# freq         1                   2                   2                  2
#
#                       High             High.1              High.2   Low  \
# count                 2037               2037                2037  2037
# unique                2035               2036                1978  2037
# top     275.42999267578125  286.4996930408869  198.60000610351562  AAPL
# freq                     2                  2                   3     1
#
#                     Low.1              Low.2               Open  \
# count                2037               2037               2037
# unique               2036               1992               2036
# ...

# %%
df.columns
# Out:
# Index(['Price', 'Close', 'Close.1', 'Close.2', 'High', 'High.1', 'High.2',
#        'Low', 'Low.1', 'Low.2', 'Open', 'Open.1', 'Open.2', 'Volume',
#        'Volume.1', 'Volume.2'],
#       dtype='object')

# %%
df.isnull().any(axis=1).sum()
df=df.dropna()

# %%
df = df[df['Price'] != 'Ticker']

# %%
df.head()
# Out:
#         Price               Close            Close.1             Close.2  \
# 2  2018-01-02   40.34188461303711  79.05035400390625  21.368667602539062
# 3  2018-01-03   40.33486557006836  79.41828155517578  21.149999618530273
# 4  2018-01-04  40.522220611572266  80.11727142333984  20.974666595458984
# 5  2018-01-05  40.983577728271484  81.11056518554688   21.10533332824707
# 6  2018-01-08   40.83134078979492   81.1933364868164   22.42733383178711
#
#                 High             High.1              High.2  \
# 2   40.3512542876815   79.3814555361966  21.474000930786133
# 3  40.87819243452449  79.56544097743182  21.683332443237305
# 4  40.62526561027816  80.62312314498602   21.23666763305664
# 5  41.07022757766769  81.31290584615176   21.14933204650879
# 6  41.12642116433384   81.4692568432421  22.468000411987305
#
#                   Low              Low.1               Low.2  \
# 2   39.63930910102925  78.63648059701545  20.733333587646484
# ...

# %%
df = df.rename(columns={'Price':'Date'})
df.head()
# Out:
#          Date               Close            Close.1             Close.2  \
# 2  2018-01-02   40.34188461303711  79.05035400390625  21.368667602539062
# 3  2018-01-03   40.33486557006836  79.41828155517578  21.149999618530273
# 4  2018-01-04  40.522220611572266  80.11727142333984  20.974666595458984
# 5  2018-01-05  40.983577728271484  81.11056518554688   21.10533332824707
# 6  2018-01-08   40.83134078979492   81.1933364868164   22.42733383178711
#
#                 High             High.1              High.2  \
# 2   40.3512542876815   79.3814555361966  21.474000930786133
# 3  40.87819243452449  79.56544097743182  21.683332443237305
# 4  40.62526561027816  80.62312314498602   21.23666763305664
# 5  41.07022757766769  81.31290584615176   21.14933204650879
# 6  41.12642116433384   81.4692568432421  22.468000411987305
#
#                   Low              Low.1               Low.2  \
# 2   39.63930910102925  78.63648059701545  20.733333587646484
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
(df.dtypes)
# Out:
# Date        datetime64[ns]
# Close               object
# Close.1             object
# Close.2             object
# High                object
# High.1              object
# High.2              object
# Low                 object
# Low.1               object
# Low.2               object
# Open                object
# Open.1              object
# Open.2              object
# Volume              object
# Volume.1            object
# Volume.2            object
# dtype: object

# %%
df['Date']
# Out:
# 2      2018-01-02
# 3      2018-01-03
# 4      2018-01-04
# 5      2018-01-05
# 6      2018-01-08
#           ...
# 2033   2026-02-02
# 2034   2026-02-03
# 2035   2026-02-04
# 2036   2026-02-05
# 2037   2026-02-06
# Name: Date, Length: 2036, dtype: datetime64[ns]

# %%
df=df.set_index('Date')

# %%
df
# Out:
#                          Close             Close.1             Close.2  \
# Date
# 2018-01-02   40.34188461303711   79.05035400390625  21.368667602539062
# 2018-01-03   40.33486557006836   79.41828155517578  21.149999618530273
# 2018-01-04  40.522220611572266   80.11727142333984  20.974666595458984
# 2018-01-05  40.983577728271484   81.11056518554688   21.10533332824707
# 2018-01-08   40.83134078979492    81.1933364868164   22.42733383178711
# ...                        ...                 ...                 ...
# 2026-02-02    270.010009765625   423.3699951171875  421.80999755859375
# 2026-02-03   269.4800109863281   411.2099914550781   421.9599914550781
# 2026-02-04    276.489990234375  414.19000244140625    406.010009765625
# 2026-02-05   275.9100036621094   393.6700134277344   397.2099914550781
# 2026-02-06   278.1199951171875   401.1400146484375   411.1099853515625
#
#                           High              High.1              High.2  \
# Date
# ...

# %%
df[price_cols] = df[price_cols].apply(pd.to_numeric)

plt.figure(figsize=(12,6))
plt.plot(df['Close'], label='AAPL')
plt.plot(df['Close.1'], label='MSFT')
plt.plot(df['Close.2'], label='TSLA')
plt.legend() #  Визуализация цен
plt.show()

# %%
df[['Close', 'Close.1', 'Close.2']].hist(bins=50, figsize=(12,6)); # Распределение признаков

# %%
df_returns = df.pct_change().dropna()
sns.heatmap(df_returns.corr(), cmap='cool', annot=False, vmin=-1, vmax=1)
# Out:
# <Axes: >
